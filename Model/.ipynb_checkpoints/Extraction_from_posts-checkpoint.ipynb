# %%
import xml.etree.ElementTree as ET
import string, re
import os.path,os
#cre

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def prep(text):
    text = text.lower()
    return text+'\n'

# %%
def cleanify(root,PATH):
   # '''Generates paras.txt in every subdirectory of stackexchange.'''
    strings = []
    printable = set(string.printable)
    str1 = ""

    for body in root.findall('row'):
        strings.append(body.get('Body'))

    fout = open(os.path.join(PATH,'paras.txt'),'w')
    str = ""
    for each in strings:
        each = prep(each)
        str += each

    fout.write(str)
    fout.close()

# %%
dirs = os.listdir('/home/saifullah/Desktop/Automatic-Resume-QA/Model/stackexchange')
for each in dirs:
    if each == ".DS_Store":        
        continue
    PATH = os.path.join('/home/saifullah/Desktop/Automatic-Resume-QA/Model/stackexchange',each)
    root = ET.parse(os.path.join(PATH,'Posts.xml')).getroot()
    logging.info('Generated paragraphs for',each)
    cleanify(root,PATH)
    logging.info('SUCCESS')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset1',)
# 2022-05-04 16:45:28,160 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset35',)
# 2022-05-04 16:45:28,186 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset41',)
# 2022-05-04 16:45:28,232 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset5',)
# 2022-05-04 16:45:29,072 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset11',)
# 2022-05-04 16:45:29,107 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset23',)
# 2022-05-04 16:45:29,170 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset12',)
# 2022-05-04 16:45:29,187 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset34',)
# 2022-05-04 16:45:29,212 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset32',)
# 2022-05-04 16:45:29,334 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset14',)
# 2022-05-04 16:45:29,392 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset7',)
# 2022-05-04 16:45:29,399 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset43',)
# 2022-05-04 16:45:29,481 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset31',)
# 2022-05-04 16:45:33,152 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
# ...
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset27',)
# 2022-05-04 16:45:34,782 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset2',)
# 2022-05-04 16:45:34,840 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset10',)
# 2022-05-04 16:45:34,930 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset18',)
# 2022-05-04 16:45:35,036 : INFO : SUCCESS
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 707, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 502, in dispatch_queue
#     await self.process_one()
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 491, in process_one
#     await dispatch(*args)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 398, in dispatch_shell
#     await result
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 722, in execute_request
#     reply_content = await reply_content
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 389, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/saifullah/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_38910/3658857776.py", line 7, in <cell line: 2>
#     logging.info('Generated paragraphs for',each)
# Message: 'Generated paragraphs for'
# Arguments: ('dataset33',)
# 2022-05-04 16:45:35,053 : INFO : SUCCESS

# %%
import sys
print(sys.getdefaultencoding())
# Out:
# utf-8
